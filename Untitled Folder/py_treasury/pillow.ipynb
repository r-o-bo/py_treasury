# %%
from PIL import Image

# %%
# Your task is to use the mask.png image to reveal the hidden message inside the word_matrix.png. 

shabd_matrix = Image.open("word_matrix.png")
shabd_matrix
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559>

# %%
shabd_matrix.size
# Out:
# (1015, 559)

# %%
mask = Image.open("mask.png")
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=505x251>

# %%
mask.size
# Out:
# (505, 251)

# %%
shabd_matrix = shabd_matrix.resize((505,251))
shabd_matrix.size
shabd_matrix
# Out:
# <PIL.Image.Image image mode=RGBA size=505x251>

# %%
mask.putalpha(200)
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=505x251>

# %%
shabd_matrix.paste(mask,(0,0),mask)

# %%
shabd_matrix
# Out:
# <PIL.Image.Image image mode=RGBA size=505x251>
